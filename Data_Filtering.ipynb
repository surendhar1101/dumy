# %% [markdown]
# # Data Filtering

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.shape
# Out:
# (145557, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145557 entries, 0 to 145556
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145557 non-null  object
#  1   Location       145557 non-null  object
#  2   MinTemp        144072 non-null  float64
#  3   MaxTemp        144296 non-null  float64
#  4   Rainfall       142295 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135228 non-null  object
#  8   WindGustSpeed  135291 non-null  float64
#  9   WindDir9am     134985 non-null  object
#  10  WindDir3pm     141325 non-null  object
#  11  WindSpeed9am   143789 non-null  float64
#  12  WindSpeed3pm   142494 non-null  float64
#  13  Humidity9am    142903 non-null  float64
#  14  Humidity3pm    141050 non-null  float64
#  15  Pressure9am    130492 non-null  float64
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  144072.000000  144296.000000  142295.000000  82670.000000
# mean       12.196225      23.226846       2.359786      5.468232
# std         6.397911       7.121473       8.475588      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135291.000000  143789.000000  142494.000000
# mean       7.611178      40.036994      14.041797      18.662028
# std        3.785483      13.607081       8.914488       8.809539
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# # % of null value

# %%
df.isnull().mean()*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020219
# MaxTemp           0.866327
# Rainfall          2.241046
# Evaporation      43.204380
# Sunshine         48.044409
# WindGustDir       7.096189
# WindGustSpeed     7.052907
# WindDir9am        7.263134
# WindDir3pm        2.907452
# WindSpeed9am      1.214644
# WindSpeed3pm      2.104330
# Humidity9am       1.823341
# Humidity3pm       3.096381
# Pressure9am      10.349897
# Pressure3pm      10.324478
# Cloud9am         38.450916
# Cloud3pm         40.833488
# Temp9am           1.213957
# Temp3pm           2.479441
# RainToday         2.241046
# RainTomorrow      2.245169
# dtype: float64

# %%
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# ### Dropping the dublicate values

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# ## Drop all NULL or NAN values

# %%
df1=df.copy()

# %%
df1.shape
# Out:
# (145460, 23)

# %%
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (56420, 23)

# %%
df1.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  01-01-2009    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  02-01-2009    Cobar     18.4     28.9       0.0         14.8      13.0
# 6052  04-01-2009    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  05-01-2009    Cobar     21.9     38.4       0.0         11.4      12.2
# 6054  06-01-2009    Cobar     24.2     41.0       0.0         11.2       8.4
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 6049         SSW           48.0        ENE  ...        20.0         13.0
# 6050           S           37.0        SSE  ...        30.0          8.0
# 6052         NNE           46.0        NNE  ...        42.0         22.0
# 6053         WNW           31.0        WNW  ...        37.0         22.0
# 6054         WNW           35.0         NW  ...        19.0         15.0
#
# ...

# %% [markdown]
# ## Dropping values for a particular column

# %%
df2=df.copy()

# %%
df2.shape
# Out:
# (145460, 23)

# %%
df2.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df2.drop(columns=['Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm','Evaporation'],inplace=True)

# %%
df2.shape
# Out:
# (145460, 18)

# %%
df2.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  WindSpeed9am  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN          20.0
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN           4.0
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN          19.0
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN          11.0
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN           7.0
#
#    WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0          24.0         71.0         22.0       1007.7       1007.1       8.0
# 1          22.0         44.0         25.0       1010.6       1007.8       NaN
# 2          26.0         38.0         30.0       1007.6       1008.7       NaN
# 3           9.0         45.0         16.0       1017.6       1012.8       NaN
# 4          20.0         82.0         33.0       1010.8       1006.0       7.0
#
# ...

# %% [markdown]
# ## Fill all the null values

# %%
df3=df.copy()

# %%
df3.fillna("hello",inplace=True)

# %%
df3.head()
# Out:
#          Date Location MinTemp MaxTemp Rainfall Evaporation Sunshine  \
# 0  01-12-2008   Albury    13.4    22.9      0.6       hello    hello
# 1  02-12-2008   Albury     7.4    25.1      0.0       hello    hello
# 2  03-12-2008   Albury    12.9    25.7      0.0       hello    hello
# 3  04-12-2008   Albury     9.2    28.0      0.0       hello    hello
# 4  05-12-2008   Albury    17.5    32.3      1.0       hello    hello
#
#   WindGustDir WindGustSpeed WindDir9am  ... Humidity9am Humidity3pm  \
# 0           W          44.0          W  ...        71.0        22.0
# 1         WNW          44.0        NNW  ...        44.0        25.0
# 2         WSW          46.0          W  ...        38.0        30.0
# 3          NE          24.0         SE  ...        45.0        16.0
# 4           W          41.0        ENE  ...        82.0        33.0
#
#   Pressure9am Pressure3pm Cloud9am Cloud3pm Temp9am Temp3pm RainToday  \
# ...

# %% [markdown]
# ## Fill for a specific column

# %%
df4=df.copy()

# %%
df4.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df4['Evaporation'].fillna("mode",inplace=True)

# %%
df4['Evaporation']
# Out:
# 0         mode
# 1         mode
# 2         mode
# 3         mode
# 4         mode
#           ...
# 145455    mode
# 145456    mode
# 145457    mode
# 145458    mode
# 145459    mode
# Name: Evaporation, Length: 145460, dtype: object
